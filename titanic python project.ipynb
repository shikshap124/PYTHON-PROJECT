# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import sklearn
import seaborn as sns

# %%
full_data=pd.read_csv(r"C:\Users\salon\OneDrive\Desktop\titanic_dataset.csv")
full_data.shape
# Out:
# (891, 12)

# %%
full_data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
sns.histplot(full_data['Parch'],kde=False)
plt.show()

# %%
sns.histplot(full_data['Age'],fill=True)
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8,8))  # Ensure plt is imported correctly
sns.histplot(full_data['Age'], kde=True, bins=30)  # kde=True adds a KDE line
plt.show()

# %%
sns.relplot(x="Age",y="Fare",col="Pclass",hue="Sex",style="Sex",kind="line",data=full_data)
plt.show()

# %%
plt.figure(figsize=(8,8))
sns.scatterplot(x="Age", y="Fare", hue="Sex", data=full_data)
plt.show()

# %%
plt.figure(figsize=(8,8))
sns.scatterplot(x="Age", y="Fare", hue="Sex", data=full_data)
plt.show()

# %%
plt.figure(figsize=(8,8))
sns.barplot(x="Age", y="Fare", hue="Sex", data=full_data)
plt.show()

# %%
plt.figure(figsize=(8,8))
sns.swarmplot(x="Sex", y="Age", hue="Sex", data=full_data)
plt.show()

# %%
sns.violinplot(x="Survived",y="Age",hue="Sex" , data=full_data)
plt.show()

# %%
sns.countplot(x="Survived" ,data=full_data,palette="Blues")
plt.show()

# %%
plt.figure(figsize=(8,8))
sns.swarmplot(x="Sex",y="Age",hue="Sex" , data=full_data)
plt.show()

# %%
plt.figure(figsize=(8,8))
sns.boxplot(x="Survived",y="Age" , data=full_data)
plt.show()

# %%
numeric_data=full_data.select_dtypes(include=["number"])
plt.subplots(figsize=(10,10))
sns.heatmap(numeric_data.corr(),cmap="YlGnBu",annot=True,fmt=".2f")
plt.show()

# %%
g=sns.FacetGrid(full_data,col="Survived",row="Pclass")
g.map(plt.hist,"Age")
g.add_legend()
plt.show()

# %%
full_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
sns.heatmap(full_data.isnull(),yticklabels=False,cbar=False,cmap='tab20c_r')
plt.tittle("Missing Data':Training set")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[101], line 2
#       1 sns.heatmap(full_data.isnull(),yticklabels=False,cbar=False,cmap='tab20c_r')
# ----> 2 plt.tittle("Missing Data':Training set")
#       3 plt.show()
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'tittle'

# %%
plt.figure(figsize=(10,7))
sns.boxplot(x='Pclass',y='Age',data=full_data,palette='GnBu_d').set_title()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[102], line 2
#       1 plt.figure(figsize=(10,7))
# ----> 2 sns.boxplot(x='Pclass',y='Age',data=full_data,palette='GnBu_d').set_title()
#
# TypeError: Axes.set_title() missing 1 required positional argument: 'label'

# %%
def impute_age(cols):
    Age=cols[0]
    Pclass=cols[1]
    if pd.isnull(Age):
        if Pclass==1:
            return 37
        elif Pclass==2:
            return 29
        else:
            return 24
    else:
        return Age
full_data['Age']=full_data[['Age','Pclass']].apply(impute_age,axis=1)
print(full_data)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female  24.0      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
full_data.drop("Cabin",axis = 1,inplace = True,errors='ignore')

# %%
full_data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female  24.0      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Embarked
# 0        0         A/5 21171   7.2500        S
# 1        0          PC 17599  71.2833        C
# 2        0  STON/O2. 3101282   7.9250        S
# 3        0            113803  53.1000        S
# 4        0            373450   8.0500        S
# ..     ...               ...      ...      ...
# 886      0            211536  13.0000        S
# 887      0            112053  30.0000        S
# 888      2        W./C. 6607  23.4500        S
# 889      0            111369  30.0000        C
# 890      0            370376   7.7500        Q
#
# [891 rows x 11 columns]

# %%
full_data.drop(['Name','Ticket'],axis=1,inplace=True)
objcat=['Sex','Embarked']
for colname in objcat:
    full_data[colname]=full_data[colname].astype('category')

# %%
full_data
# Out:
#      PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch     Fare  \
# 0              1         0       3    male  22.0      1      0   7.2500
# 1              2         1       1  female  38.0      1      0  71.2833
# 2              3         1       3  female  26.0      0      0   7.9250
# 3              4         1       1  female  35.0      1      0  53.1000
# 4              5         0       3    male  35.0      0      0   8.0500
# ..           ...       ...     ...     ...   ...    ...    ...      ...
# 886          887         0       2    male  27.0      0      0  13.0000
# 887          888         1       1  female  19.0      0      0  30.0000
# 888          889         0       3  female  24.0      1      2  23.4500
# 889          890         1       1    male  26.0      0      0  30.0000
# 890          891         0       3    male  32.0      0      0   7.7500
#
#     Embarked
# 0          S
# 1          C
# 2          S
# 3          S
# 4          S
# ..       ...
# 886        S
# 887        S
# 888        S
# 889        C
# 890        Q
#
# [891 rows x 9 columns]

# %%
full_data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.066409    0.523008
# std     257.353842    0.486592    0.836071   13.244532    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   22.000000    0.000000
# 50%     446.000000    0.000000    3.000000   26.000000    0.000000
# 75%     668.500000    1.000000    3.000000   37.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
full_data.drop('PassengerId',inplace=True,axis=1,errors='ignore')

# %%
full_data.shape
# Out:
# (891, 8)

# %%
full_data.select_dtypes(['category']).columns
# Out:
# Index(['Sex', 'Embarked'], dtype='object')

# %%
sex= pd.get_dummies(full_data['Sex'], drop_first = True)
embarked= pd.get_dummies(full_data['Embarked'], drop_first=True)

# %%
full_data.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0         0       3    male  22.0      1      0   7.2500        S
# 1         1       1  female  38.0      1      0  71.2833        C
# 2         1       3  female  26.0      0      0   7.9250        S
# 3         1       1  female  35.0      1      0  53.1000        S
# 4         0       3    male  35.0      0      0   8.0500        S

# %%
full_data=pd.concat([full_data, sex, embarked],axis=1)
full_data.head(5)
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked  male  Q  S
# 0         0       3    male  22.0      1      0   7.2500        S     1  0  1
# 1         1       1  female  38.0      1      0  71.2833        C     0  0  0
# 2         1       3  female  26.0      0      0   7.9250        S     0  0  1
# 3         1       1  female  35.0      1      0  53.1000        S     0  0  1
# 4         0       3    male  35.0      0      0   8.0500        S     1  0  1

# %%
full_data.drop(['Sex','Embarked'],axis=1, inplace=True)
print('Train_data shape', full_data.shape)
full_data.head()
# Out:
# Train_data shape (891, 9)
#    Survived  Pclass   Age  SibSp  Parch     Fare  male  Q  S
# 0         0       3  22.0      1      0   7.2500     1  0  1
# 1         1       1  38.0      1      0  71.2833     0  0  0
# 2         1       3  26.0      0      0   7.9250     0  0  1
# 3         1       1  35.0      1      0  53.1000     0  0  1
# 4         0       3  35.0      0      0   8.0500     1  0  1

# %%
full_data.drop("survived")
